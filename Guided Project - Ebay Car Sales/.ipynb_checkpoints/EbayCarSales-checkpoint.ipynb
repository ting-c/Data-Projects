# %% [markdown]
# # Ebay Car Sales
#
# In this project, we'll work with a modified dataset of used cars from eBay Kleinanzeigen, a classifieds section of the German eBay website. The original dataset was obtained from [Kaggle](https://www.kaggle.com/orgesleka/used-cars-database/data.). The modified dataset took a sampled of  50,000 data points from the full dataset and modified a bit to more closely resemble what we would expect from a scraped dataset. The aim of this project is to clean the data and analyze the included used car listings.
#
# The data dictionary provided with data is as follows:
#
# - dateCrawled - When this ad was first crawled. All field-values are taken from this date.
# - name - Name of the car.
# - seller - Whether the seller is private or a dealer.
# - offerType - The type of listing
# - price - The price on the ad to sell the car.
# - abtest - Whether the listing is included in an A/B test.
# - vehicleType - The vehicle Type.
# - yearOfRegistration - The year in which the car was first registered.
# - gearbox - The transmission type.
# - powerPS - The power of the car in PS.
# - model - The car model name.
# - kilometer - How many kilometers the car has driven.
# - monthOfRegistration - The month in which the car was first registered.
# - fuelType - What type of fuel the car uses.
# - brand - The brand of the car.
# - notRepairedDamage - If the car has a damage which is not yet repaired.
# - dateCreated - The date on which the eBay listing was created.
# - nrOfPictures - The number of pictures in the ad.
# - postalCode - The postal code for the location of the vehicle.
# - lastSeenOnline - When the crawler saw this ad last online.

# %%
import pandas as pd
import numpy as np
autos = pd.read_csv('autos.csv', encoding = 'Latin-1') # using Latin-1 encoding as default gives and error

# %%
#displaying the file
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info() # print some info about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# Based on the information provided above, there are some missing values(null) in some columns( e.g. vehicle type, model, fuel and notRepairedDamage. The gearbox and model columns have around 700 missing values which is not too bad for a dataset this size. However, there are almost 10,000 missing values for notRepairedDamage. We will need to analyse the data set further to make a decision on how to deal with these missing values. Also, most of the columns contain strings with few integer columns.

# %% [markdown]
# Let's convert the column names from camelcase to snakecase and reword some of the column names based on the data dictionary to be more descriptive. We'll change the names from camelcase to snakecase.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code','last_seen']
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# Let's have a look at the modified column names.

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# Now we'll do some basic data exploration to determine what other cleaning tasks need to be done.
#
#
# Initially we will look for text columns where all or almost all values are the same. These can often be dropped as they don't have useful information for analysis.

# %%
autos.describe(include='all')#descriptive statistics for all columns
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-23 18:39:34  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %%
autos['seller'].value_counts() # Get the unique entries for seller
# Out:
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos['offer_type'].value_counts()# Get the unique entries for offer type
# Out:
# Angebot    49999
# Gesuch         1
# Name: offer_type, dtype: int64

# %% [markdown]
# - The seller and offer_type columns have very similar values and don't offer much info for analysis.
#
# - The nr_of_pictures column have values of 0s which is odd, we definitely need to investigate that further.

# %%
autos['nr_of_pictures'].value_counts()
# Out:
# 0    50000
# Name: nr_of_pictures, dtype: int64

# %% [markdown]
# There are 50000 entries of zeros for nr_of_pictures so we will remove this column for further analysis.

# %%
autos.drop('nr_of_pictures', axis = 1)
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %% [markdown]
# We'll need to change the price and odometer columns which are numeric values currently stored as text.

# %%
# Removing the comma and $ sign
autos['price'] = autos['price'].str.replace('$', '')
autos['price'] = autos['price'].str.replace(',', '')
# Change the data type from object to integer
autos['price'] = autos['price'].astype(int)
autos['price']
# Out:
# 0         5000
# 1         8500
# 2         8990
# 3         4350
# 4         1350
# 5         7900
# 6          300
# 7         1990
# 8          250
# 9          590
# 10         999
# 11         350
# 12        5299
# 13        1350
# 14        3999
# 15       18900
# 16         350
# 17        5500
# 18         300
# 19        4150
# 20        3500
# 21       41500
# 22       25450
# 23        7999
# 24       48500
# 25          90
# 26         777
# 27           0
# 28        5250
# 29        4999
#          ...
# 49970    15800
# 49971      950
# 49972     3300
# 49973     6000
# 49974        0
# 49975     9700
# 49976     5900
# 49977     5500
# 49978      900
# 49979    11000
# 49980      400
# 49981     2000
# 49982     1950
# 49983      600
# 49984        0
# 49985     1000
# 49986    15900
# 49987    21990
# 49988     9550
# 49989      150
# 49990    17500
# 49991      500
# 49992     4800
# 49993     1650
# 49994     5000
# 49995    24900
# 49996     1980
# ...

# %%
# Removing comma and km
autos['odometer'] = autos['odometer'].str.replace('km', '')
autos['odometer'] = autos['odometer'].str.replace(',', '')
# Change the data type from object to integer
autos['odometer'] = autos['odometer'].astype(int)
print(autos['odometer'])
# Out:
# 0        150000
# 1        150000
# 2         70000
# 3         70000
# 4        150000
# 5        150000
# 6        150000
# 7        150000
# 8        150000
# 9        150000
# 10       150000
# 11       150000
# 12        50000
# 13       150000
# 14       150000
# 15        80000
# 16       150000
# 17       150000
# 18       150000
# 19       150000
# 20       150000
# 21       150000
# 22        10000
# 23       150000
# 24        30000
# 25       150000
# 26       125000
# 27       150000
# 28       150000
# 29       150000
#           ...
# 49970     60000
# 49971    150000
# 49972    150000
# 49973    150000
# 49974    150000
# 49975    100000
# 49976    150000
# 49977    150000
# 49978    150000
# 49979     70000
# 49980    125000
# 49981    150000
# 49982     90000
# 49983    150000
# 49984    150000
# 49985    150000
# 49986    125000
# 49987     50000
# 49988    150000
# 49989    150000
# 49990     30000
# 49991    150000
# 49992    125000
# 49993    150000
# ...

# %%
# Rename 'odometer' column to 'odometer_km' as we took remove 'km'
autos.rename({'odometer':'odometer_km'}, axis=1, inplace=True) 
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot   5000  control          bus               2004
# 1  privat    Angebot   8500  control    limousine               1997
# 2  privat    Angebot   8990     test    limousine               2009
# 3  privat    Angebot   4350  control   kleinwagen               2007
# 4  privat    Angebot   1350     test        kombi               2003
#
#      gearbox  power_ps   model  odometer_km  registration_month fuel_type  \
# ...

# %% [markdown]
# We'll continue analysing the odometer_km and price columns.
#
# #### Odometer km

# %%
autos['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos['odometer_km'].value_counts().sort_index(ascending =False)
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# 5000        967
# Name: odometer_km, dtype: int64

# %% [markdown]
# There are more cars with higher mileage. The majority of sales has the highest mileage 150,000 km and there are some fairly new cars being sold at 5000 km.
#
#
# #### Price

# %%
autos['price'].value_counts()
# Out:
# 0         1421
# 500        781
# 1500       734
# 2500       643
# 1000       639
# 1200       639
# 600        531
# 800        498
# 3500       498
# 2000       460
# 999        434
# 750        433
# 900        420
# 650        419
# 850        410
# 700        395
# 4500       394
# 300        384
# 2200       382
# 950        379
# 1100       376
# 1300       371
# 3000       365
# 550        356
# 1800       355
# 5500       340
# 1250       335
# 350        335
# 1600       327
# 1999       322
#           ...
# 46200        1
# 29600        1
# 13480        1
# 21700        1
# 7373         1
# 3279         1
# 4286         1
# 188          1
# 17830        1
# 9130         1
# 910          1
# 238          1
# 2671         1
# 69900        1
# 151990       1
# 2479         1
# 4510         1
# 86500        1
# 47499        1
# 16998        1
# 27299        1
# 41850        1
# 4780         1
# 686          1
# 6495         1
# 20790        1
# 8970         1
# ...

# %%
autos['price'].describe(include=all)
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %% [markdown]
# There are quite a lot of cars being sold for free (1421) and the highest is 100,000,000 which is probably too high for a car. Let's have a look at the top rows of the price columns.

# %%
autos['price'].value_counts().sort_index(ascending=False).head(20)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# 350000      1
# 345000      1
# 299000      1
# 295000      1
# 265000      1
# 259000      1
# 250000      1
# 220000      1
# 198000      1
# 197000      1
# Name: price, dtype: int64

# %% [markdown]
# The max price is actually 99,999,999 rather than 100,000,000.

# %%
autos_price_max = autos['price'].value_counts().sort_index(ascending=False).head(20)
autos_name_max_price = autos[autos['price'] > 350000]
autos_name_max_price.sort_values('price',ascending = False)
# Out:
#               date_crawled                                               name  \
# 39705  2016-03-22 14:58:27                        Tausch_gegen_gleichwertiges
# 42221  2016-03-08 20:39:05                                  Leasinguebernahme
# 27371  2016-03-09 15:45:47                                         Fiat_Punto
# 39377  2016-03-08 23:53:51                        Tausche_volvo_v40_gegen_van
# 47598  2016-03-31 18:56:54  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 24384  2016-03-21 13:57:51                            Schlachte_Golf_3_gt_tdi
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 47634  2016-04-04 21:25:21                                        Ferrari_FXX
# 7814   2016-04-04 11:53:31                                        Ferrari_F40
# 22947  2016-03-22 12:54:19                         Bmw_530d_zum_ausschlachten
# ...

# %% [markdown]
# We can see there's a big jump from a steady increase until € 350,000. We will remove all entries with above € 350,000 price tag.

# %%
autos['price'].value_counts().sort_index(ascending=False).tail(20)
# Out:
# 35       1
# 30       7
# 29       1
# 25       5
# 20       4
# 18       1
# 17       3
# 15       2
# 14       1
# 13       2
# 12       3
# 11       2
# 10       7
# 9        1
# 8        1
# 5        2
# 3        1
# 2        3
# 1      156
# 0     1421
# Name: price, dtype: int64

# %% [markdown]
# Given that ebay is an auction site so € 1 starting bids are legitimate. We'll keep these entries and above.

# %%
# Removing outliers
autos = autos[autos['price'].between (1,350000)]

# %%
autos['price'].value_counts().sort_index(ascending=False).head(20) # top end
# Out:
# 350000    1
# 345000    1
# 299000    1
# 295000    1
# 265000    1
# 259000    1
# 250000    1
# 220000    1
# 198000    1
# 197000    1
# 194000    1
# 190000    1
# 180000    1
# 175000    1
# 169999    1
# 169000    1
# 163991    1
# 163500    1
# 155000    1
# 151990    1
# Name: price, dtype: int64

# %%
autos['price'].value_counts().sort_index(ascending=False).tail(20) # bottom end
# Out:
# 40      6
# 35      1
# 30      7
# 29      1
# 25      5
# 20      4
# 18      1
# 17      3
# 15      2
# 14      1
# 13      2
# 12      3
# 11      2
# 10      7
# 9       1
# 8       1
# 5       2
# 3       1
# 2       3
# 1     156
# Name: price, dtype: int64

# %% [markdown]
# ### Date Columns and Date Range
#
# - `date_crawled`:       added by the crawler
# - `last_seen`:          added by the crawler
# - `ad_created`:         from the website
# - `registration_month`: from the website
# - `registration_year`:  from the website
#
# The date_crawled, last_seen, and ad_created columns are all identified as string values by pandas. Because these three columns are represented as strings, we need to convert the data into a numerical representation so we can understand it quantitatively.
#
# The registration_month and registration_year columns are represented as numeric values, so we can use methods like Series.describe() to understand the distribution

# %%
# display the first 5 rows of date_crawled, last_seen, and ad_created columns 

autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %% [markdown]
# The first 10 characters represent the dates so we can extract just the date values by selecting the first 10 characters in each column.

# %%
autos['date_crawled'].str[:10]
# Out:
# 0        2016-03-26
# 1        2016-04-04
# 2        2016-03-26
# 3        2016-03-12
# 4        2016-04-01
# 5        2016-03-21
# 6        2016-03-20
# 7        2016-03-16
# 8        2016-03-22
# 9        2016-03-16
# 10       2016-03-15
# 11       2016-03-16
# 12       2016-03-31
# 13       2016-03-23
# 14       2016-03-23
# 15       2016-04-01
# 16       2016-03-16
# 17       2016-03-29
# 18       2016-03-26
# 19       2016-03-17
# 20       2016-03-05
# 21       2016-03-06
# 22       2016-03-28
# 23       2016-03-10
# 24       2016-04-03
# 25       2016-03-21
# 26       2016-04-03
# 28       2016-03-19
# 29       2016-04-02
# 30       2016-03-14
#             ...
# 49968    2016-04-01
# 49969    2016-03-17
# 49970    2016-03-21
# 49971    2016-03-29
# 49972    2016-03-26
# 49973    2016-03-27
# 49975    2016-03-27
# 49976    2016-03-19
# 49977    2016-03-31
# 49978    2016-04-04
# 49979    2016-03-20
# 49980    2016-03-12
# 49981    2016-03-15
# 49982    2016-03-29
# ...

# %%
# frequency table with proportion
autos['date_crawled'].str[:10].value_counts(normalize = True ,dropna = False).sort_index(ascending = True )
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: date_crawled, dtype: float64

# %% [markdown]
# The distribution of dates is quite uniform across the range.

# %%
autos['registration_year'].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The registration year column looks fine apart from the min(year 1000) and max (year 9999) which needs to be looked at.

# %%
autos['registration_year'].value_counts().sort_index(ascending = True)
# Out:
# 1000       1
# 1001       1
# 1111       1
# 1800       2
# 1910       5
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       3
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       4
# 1957       2
# 1958       4
# 1959       6
# 1960      23
# 1961       6
# 1962       4
# 1963       8
# 1964      12
#         ...
# 2000    3156
# 2001    2636
# 2002    2486
# 2003    2699
# 2004    2703
# 2005    2936
# 2006    2670
# 2007    2277
# 2008    2215
# 2009    2085
# 2010    1589
# 2011    1623
# 2012    1310
# 2013     803
# 2014     663
# 2015     392
# 2016    1220
# 2017    1392
# 2018     470
# 2019       2
# 2800       1
# 4100       1
# 4500       1
# 4800       1
# 5000       4
# 5911       1
# 6200       1
# 8888       1
# 9000       1
# 9999       3
# Name: registration_year, Length: 95, dtype: int64

# %% [markdown]
# We will remove the entries with registration year above 2016 as the dataset was created on year 2016 and we'll also remove cars below 1910.

# %%
# Removing outliers
autos = autos[autos['registration_year'].between (1910,2016)]

# %%
autos['registration_year'].value_counts().sort_index(ascending = True)
# Out:
# 1910       5
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       3
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       4
# 1957       2
# 1958       4
# 1959       6
# 1960      23
# 1961       6
# 1962       4
# 1963       8
# 1964      12
# 1965      17
# 1966      22
# 1967      26
# 1968      26
#         ...
# 1987      72
# 1988     135
# 1989     174
# 1990     347
# 1991     339
# 1992     370
# 1993     425
# 1994     629
# 1995    1227
# 1996    1373
# 1997    1951
# 1998    2363
# 1999    2897
# 2000    3156
# 2001    2636
# 2002    2486
# 2003    2699
# 2004    2703
# 2005    2936
# 2006    2670
# 2007    2277
# 2008    2215
# 2009    2085
# 2010    1589
# 2011    1623
# 2012    1310
# 2013     803
# 2014     663
# 2015     392
# 2016    1220
# Name: registration_year, Length: 78, dtype: int64

# %%
# Distribution 
autos['registration_year'].describe()
# Out:
# count    46681.000000
# mean      2002.910756
# std          7.185103
# min       1910.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The standard deviation has decreased from around 88 to 7 which indicates the outliers has had a big impact on the figure and now the registration_year colomn has values that is more suitable for further analysis

# %% [markdown]
# ### Variations across different car brands
#
# We're going to look at the the top 20 brands of car in the dataset.

# %%
#frequency table with proportion
top_20_brand = autos['brand'].value_counts(normalize = True ,dropna = False).sort_values(ascending = False).head(20)
top_20_brand
# Out:
# volkswagen        0.211264
# bmw               0.110045
# opel              0.107581
# mercedes_benz     0.096463
# audi              0.086566
# ford              0.069900
# renault           0.047150
# peugeot           0.029841
# fiat              0.025642
# seat              0.018273
# skoda             0.016409
# nissan            0.015274
# mazda             0.015188
# smart             0.014160
# citroen           0.014010
# toyota            0.012703
# hyundai           0.010025
# sonstige_autos    0.009811
# volvo             0.009147
# mini              0.008762
# Name: brand, dtype: float64

# %% [markdown]
# The table above shows that volkswagen dominated the ebay site with more than 20% of the dateset while bmw , opel , mercedes_benz  and audi represent above 40 % together. We'll focus on these top 5 brands for the next section of our analysis.

# %%
top_5_brand = ['volkswagen' , 'bmw', 'opel', 'mercedes_benz', 'audi']
top_5_brand
# Out:
# ['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi']

# %% [markdown]
# ### Average Price

# %%
mean_price_all_brand= {}
for brand in top_5_brand:
    selected_rows = autos[autos['brand'] == brand]    
    brand_price = selected_rows['price']
    
    total_brand_price = 0
    for price in brand_price:
        total_brand_price += price
    mean_brand = round((total_brand_price / len(brand_price)),2)
    mean_price_all_brand[brand] = mean_brand    
    
print(mean_price_all_brand)
# Out:
# {'opel': 2975.24, 'audi': 9336.69, 'mercedes_benz': 8628.45, 'volkswagen': 5402.41, 'bmw': 8332.82}

# %%
# Displaying the dict as in a table
price_series = pd.Series(mean_price_all_brand)
mean_price = pd.DataFrame(price_series, columns=["mean_price"])
mean_price
# Out:
#                mean_price
# audi              9336.69
# bmw               8332.82
# mercedes_benz     8628.45
# opel              2975.24
# volkswagen        5402.41

# %% [markdown]
# Audi has the highest mean advertised selling price while Opel has the lowest selling price.

# %% [markdown]
# ### Average Odometer

# %%
mean_odometer_all_brand= {}
for brand in top_5_brand:
    selected_rows = autos[autos['brand'] == brand]    
    brand_odometer = selected_rows['odometer_km']
    
    total_brand_odometer = 0
    for odometer in brand_odometer:
        total_brand_odometer += odometer
    mean_odometer = round(total_brand_odometer / len(brand_odometer))
    mean_odometer_all_brand[brand] = mean_odometer    
    
print(mean_odometer_all_brand)
# Out:
# {'opel': 129310, 'audi': 129157, 'mercedes_benz': 130788, 'volkswagen': 128707, 'bmw': 132573}

# %%
odo_series = pd.Series(mean_odometer_all_brand)
odometer_info = pd.DataFrame(odo_series, columns=["mean_odometer_in_km"])
odometer_info
# Out:
#                mean_odometer_in_km
# audi                        129157
# bmw                         132573
# mercedes_benz               130788
# opel                        129310
# volkswagen                  128707

# %% [markdown]
# The mean odometer is very uniform across all top 5 brands which could mean that Ebay sites tends to have cars over 129,000 km mileage on sale.

# %% [markdown]
# ### Average Registration Year

# %%
mean_reg_all_brand= {}
for brand in top_5_brand:
    selected_rows = autos[autos['brand'] == brand]    
    brand_reg = selected_rows['registration_year']
    
    total_brand_reg = 0
    for reg in brand_reg:
        total_brand_reg += reg
    mean_reg = round((total_brand_reg / len(brand_reg)),2)
    mean_reg_all_brand[brand] = mean_reg    
    
print(mean_reg_all_brand)
# Out:
# {'opel': 2002.22, 'audi': 2004.16, 'mercedes_benz': 2002.03, 'volkswagen': 2002.47, 'bmw': 2003.04}

# %%
reg_series = pd.Series(mean_reg_all_brand)
reg_info = pd.DataFrame(reg_series, columns=["mean_registration_year"])
reg_info
# Out:
#                mean_registration_year
# audi                          2004.16
# bmw                           2003.04
# mercedes_benz                 2002.03
# opel                          2002.22
# volkswagen                    2002.47

# %% [markdown]
# The average registration year for the top 5 brands are similar with Audi cars tends to be newer and mercedes_benz cars tends to be older.

# %%
# Putting all columns in one table
reg_info["mean_price"] = mean_price
reg_info["odometer_info"] = odometer_info
reg_info
# Out:
#                mean_registration_year  mean_price  odometer_info
# audi                          2004.16     9336.69         129157
# bmw                           2003.04     8332.82         132573
# mercedes_benz                 2002.03     8628.45         130788
# opel                          2002.22     2975.24         129310
# volkswagen                    2002.47     5402.41         128707

# %% [markdown]
# ## Conclusion
#
# The range of car registration and mileage does not vary as much as the prices do by top 5 brand advertised on Ebay. There is a slight positive correlation to the more expensive vehicles having higher mileage, with the less expensive vehicles having lower mileage.
